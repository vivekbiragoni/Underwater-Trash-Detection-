# %%
pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 14.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO, checks, hub
checks()

hub.login('d037a521ea26cec7c47a8eed3da35b7e3dba26a01a')

model = YOLO('https://hub.ultralytics.com/models/dTVXS6JkzcxVNd85tOdU')
results = model.train()
# Out:
# Ultralytics 8.3.75 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6133.0/8062.4 GB disk)
# requirements: Ultralytics requirement ['hub-sdk>=0.0.12'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.9/42.9 kB 3.0 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 3.4s, installed 1 package: ['hub-sdk>=0.0.12']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# Ultralytics HUB: New authentication successful ✅
# Ultralytics HUB: View model at https://hub.ultralytics.com/models/dTVXS6JkzcxVNd85tOdU 🚀
# Ultralytics 8.3.75 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
import shutil

# Define the path to the folder you want to zip
folder_to_zip = '/kaggle/working/runs/detect/train3'

# Define the name and path of the output zip file
output_zip = '/kaggle/working/runs/detect/train3_zip'

# Create a zip file
shutil.make_archive(output_zip.replace('.zip', ''), 'zip', folder_to_zip)

print(f'Folder {folder_to_zip} has been zipped to {output_zip}')
# Out:
# Folder /kaggle/working/runs/detect/train3 has been zipped to /kaggle/working/runs/detect/train3_zip
